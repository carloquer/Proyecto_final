# %% [markdown]
# ### Importación de Librerías

# %%
import simpy
import pandas as pd
import random

# %% [markdown]
# ### Cabina de Venta

# %%
class TicketBooth:
    def __init__(self, env, name, service_time, capacity):
        self.env = env
        self.name = name
        self.service_time = service_time
        self.resource = simpy.Resource(env, capacity=capacity)

        # DataFrames para seguimiento
        self.dfBooth = pd.DataFrame({
            "name": [name],
            "service_time": [service_time]
        })
        self.dfEvents = pd.DataFrame()

    def sell_ticket(self, customer_name):
        yield self.env.timeout(random.uniform(20, 60))  # Tiempo de servicio aleatorio
        print(f"{self.env.now}: {self.name} vendió un boleto a {customer_name} en {self.service_time} segundos.")
        df = pd.DataFrame({
            "time": [self.env.now],
            "booth": [self.name],
            "customer": [customer_name],
            "event": ["ticket sold"]
        })
        self.dfEvents = pd.concat([self.dfEvents, df])

# %% [markdown]
# ### Cliente

# %%
class Customer:
    def __init__(self, env, name, ticket_booth):
        self.env = env
        self.name = name
        self.ticket_booth = ticket_booth
        env.process(self.wait_in_line())

        # DataFrame para seguimiento
        self.dfCustomer = pd.DataFrame({
            "name": [name],
            "ticket_booth": [ticket_booth.name]
        })
        self.dfEvents = pd.DataFrame()

    def wait_in_line(self):
        print(f"{self.env.now}: {self.name} está esperando en {self.ticket_booth.name}.")
        df = pd.DataFrame({
            "time": [self.env.now],
            "booth": [self.ticket_booth.name],
            "customer": [self.name],
            "event": ["waiting in line"]
        })
        self.dfEvents = pd.concat([self.dfEvents, df])
        
        with self.ticket_booth.resource.request() as request:
            yield request
            print(f"{self.env.now}: {self.name} está listo para ser atendido en {self.ticket_booth.name}.")
            yield self.env.process(self.ticket_booth.sell_ticket(self.name))
            print(f"{self.env.now}: {self.name} fue atendido en {self.ticket_booth.name} y compró su boleto.")
            df = pd.DataFrame({
                "time": [self.env.now],
                "booth": [self.ticket_booth.name],
                "customer": [self.name],
                "event": ["finished"]
            })
            self.dfEvents = pd.concat([self.dfEvents, df])
            yield self.env.timeout(1)

# %% [markdown]
# ### Setup

# %%
class Setup:
    def __init__(self, env, num_booths, num_customers):
        self.env = env
        self.customers = []
        self.num_customers = num_customers
        self.booths = [TicketBooth(
            env,
            f"Booth {i}",
            random.randint(20, 60),  # Tiempo de servicio aleatorio entre 20-60 segundos
            capacity=1  # Cada cabina puede atender a un cliente a la vez
        ) for i in range(num_booths)]

        env.process(self.customer_arrival())

    def customer_arrival(self):
        for i in range(self.num_customers):
            self.customers.append(Customer(
                env,
                f"Customer {i}",
                random.choice(self.booths)
            ))
            yield self.env.timeout(random.expovariate(1/50))  # Distribución exponencial para llegadas

# %% [markdown]
# ### Simulación

# %%
random.seed(42)
env = simpy.Environment()

setup = Setup(env, num_booths=3, num_customers=50)

env.run(until=2000)  # Simulación por 2000 segundos
# Out:
# 0: Customer 0 está esperando en Booth 2.
# 0: Customer 0 está listo para ser atendido en Booth 2.
# 16.081203203748277: Customer 1 está esperando en Booth 2.
# 21.488042398492254: Customer 2 está esperando en Booth 2.
# 28.92842952595291: Booth 2 vendió un boleto a Customer 0 en 21 segundos.
# 28.92842952595291: Customer 0 fue atendido en Booth 2 y compró su boleto.
# 29.92842952595291: Customer 1 está listo para ser atendido en Booth 2.
# 53.405982831129556: Booth 2 vendió un boleto a Customer 1 en 21 segundos.
# 53.405982831129556: Customer 1 fue atendido en Booth 2 y compró su boleto.
# 54.405982831129556: Customer 2 está listo para ser atendido en Booth 2.
# 91.28285561854037: Booth 2 vendió un boleto a Customer 2 en 21 segundos.
# 91.28285561854037: Customer 2 fue atendido en Booth 2 y compró su boleto.
# 132.85244737606126: Customer 3 está esperando en Booth 0.
# 132.85244737606126: Customer 3 está listo para ser atendido en Booth 0.
# 137.77142985898408: Customer 4 está esperando en Booth 2.
# 137.77142985898408: Customer 4 está listo para ser atendido en Booth 2.
# 139.11615004299946: Customer 5 está esperando en Booth 2.
# 162.15888311169084: Booth 0 vendió un boleto a Customer 3 en 60 segundos.
# 162.15888311169084: Customer 3 fue atendido en Booth 0 y compró su boleto.
# 165.72493588645003: Booth 2 vendió un boleto a Customer 4 en 21 segundos.
# 165.72493588645003: Customer 4 fue atendido en Booth 2 y compró su boleto.
# 166.72493588645003: Customer 5 está listo para ser atendido en Booth 2.
# 199.53610828578803: Customer 6 está esperando en Booth 1.
# 199.53610828578803: Customer 6 está listo para ser atendido en Booth 1.
# 203.50572872491637: Booth 2 vendió un boleto a Customer 5 en 21 segundos.
# 203.50572872491637: Customer 5 fue atendido en Booth 2 y compró su boleto.
# 244.02654360087615: Customer 7 está esperando en Booth 0.
# 244.02654360087615: Customer 7 está listo para ser atendido en Booth 0.
# 251.91332655290108: Booth 1 vendió un boleto a Customer 6 en 27 segundos.
# 251.91332655290108: Customer 6 fue atendido en Booth 1 y compró su boleto.
# 270.41291625595176: Booth 0 vendió un boleto a Customer 7 en 60 segundos.
# 270.41291625595176: Customer 7 fue atendido en Booth 0 y compró su boleto.
# 315.1345115134424: Customer 8 está esperando en Booth 1.
# 315.1345115134424: Customer 8 está listo para ser atendido en Booth 1.
# 335.92926583837146: Customer 9 está esperando en Booth 1.
# 341.32023579012815: Customer 10 está esperando en Booth 1.
# 341.3536915059137: Booth 1 vendió un boleto a Customer 8 en 27 segundos.
# 341.3536915059137: Customer 8 fue atendido en Booth 1 y compró su boleto.
# 342.3536915059137: Customer 9 está listo para ser atendido en Booth 1.
# 346.40617003990974: Customer 11 está esperando en Booth 2.
# 346.40617003990974: Customer 11 está listo para ser atendido en Booth 2.
# 361.7678255809621: Customer 12 está esperando en Booth 1.
# 368.1441877568336: Booth 2 vendió un boleto a Customer 11 en 21 segundos.
# 368.1441877568336: Customer 11 fue atendido en Booth 2 y compró su boleto.
# 396.2534661598121: Booth 1 vendió un boleto a Customer 9 en 27 segundos.
# 396.2534661598121: Customer 9 fue atendido en Booth 1 y compró su boleto.
# 397.2534661598121: Customer 10 está listo para ser atendido en Booth 1.
# 400.1859467824706: Customer 13 está esperando en Booth 1.
# 404.28986308536247: Customer 14 está esperando en Booth 1.
# 456.1780967189869: Booth 1 vendió un boleto a Customer 10 en 27 segundos.
# 456.1780967189869: Customer 10 fue atendido en Booth 1 y compró su boleto.
# 457.1780967189869: Customer 12 está listo para ser atendido en Booth 1.
# 492.7129123146376: Customer 15 está esperando en Booth 1.
# 501.91888681355675: Booth 1 vendió un boleto a Customer 12 en 27 segundos.
# 501.91888681355675: Customer 12 fue atendido en Booth 1 y compró su boleto.
# 502.91888681355675: Customer 13 está listo para ser atendido en Booth 1.
# 535.7737093820799: Customer 16 está esperando en Booth 0.
# 535.7737093820799: Customer 16 está listo para ser atendido en Booth 0.
# 551.1017602621537: Booth 1 vendió un boleto a Customer 13 en 27 segundos.
# 551.1017602621537: Customer 13 fue atendido en Booth 1 y compró su boleto.
# 552.1017602621537: Customer 14 está listo para ser atendido en Booth 1.
# 586.6964430136276: Booth 0 vendió un boleto a Customer 16 en 60 segundos.
# 586.6964430136276: Customer 16 fue atendido en Booth 0 y compró su boleto.
# 589.9003206003899: Customer 17 está esperando en Booth 0.
# 589.9003206003899: Customer 17 está listo para ser atendido en Booth 0.
# 611.510621088584: Booth 1 vendió un boleto a Customer 14 en 27 segundos.
# 611.510621088584: Customer 14 fue atendido en Booth 1 y compró su boleto.
# 612.510621088584: Customer 15 está listo para ser atendido en Booth 1.
# 625.1053696019566: Booth 0 vendió un boleto a Customer 17 en 60 segundos.
# 625.1053696019566: Customer 17 fue atendido en Booth 0 y compró su boleto.
# 650.6470331833215: Booth 1 vendió un boleto a Customer 15 en 27 segundos.
# 650.6470331833215: Customer 15 fue atendido en Booth 1 y compró su boleto.
# 690.5768937115433: Customer 18 está esperando en Booth 1.
# 690.5768937115433: Customer 18 está listo para ser atendido en Booth 1.
# 699.4527951523758: Customer 19 está esperando en Booth 2.
# 699.4527951523758: Customer 19 está listo para ser atendido en Booth 2.
# 714.9817612093751: Customer 20 está esperando en Booth 2.
# 718.6857565063683: Customer 21 está esperando en Booth 2.
# 724.7877217206442: Booth 1 vendió un boleto a Customer 18 en 27 segundos.
# 724.7877217206442: Customer 18 fue atendido en Booth 1 y compró su boleto.
# 728.070875774324: Customer 22 está esperando en Booth 2.
# 742.1102323154503: Customer 23 está esperando en Booth 1.
# 742.1102323154503: Customer 23 está listo para ser atendido en Booth 1.
# 756.9189786608755: Booth 2 vendió un boleto a Customer 19 en 21 segundos.
# 756.9189786608755: Customer 19 fue atendido en Booth 2 y compró su boleto.
# 757.9189786608755: Customer 20 está listo para ser atendido en Booth 2.
# 765.9681256501677: Customer 24 está esperando en Booth 2.
# 778.3665313631204: Customer 25 está esperando en Booth 1.
# 801.691166340914: Booth 1 vendió un boleto a Customer 23 en 27 segundos.
# 801.691166340914: Customer 23 fue atendido en Booth 1 y compró su boleto.
# 802.691166340914: Customer 25 está listo para ser atendido en Booth 1.
# 803.5189690550392: Booth 2 vendió un boleto a Customer 20 en 21 segundos.
# 803.5189690550392: Customer 20 fue atendido en Booth 2 y compró su boleto.
# 804.5189690550392: Customer 21 está listo para ser atendido en Booth 2.
# 833.6808919336033: Booth 2 vendió un boleto a Customer 21 en 21 segundos.
# 833.6808919336033: Customer 21 fue atendido en Booth 2 y compró su boleto.
# 834.6808919336033: Customer 22 está listo para ser atendido en Booth 2.
# 853.7311628027638: Booth 1 vendió un boleto a Customer 25 en 27 segundos.
# 853.7311628027638: Customer 25 fue atendido en Booth 1 y compró su boleto.
# 855.9649016897648: Booth 2 vendió un boleto a Customer 22 en 21 segundos.
# 855.9649016897648: Customer 22 fue atendido en Booth 2 y compró su boleto.
# 856.9649016897648: Customer 24 está listo para ser atendido en Booth 2.
# 870.8948680954958: Customer 26 está esperando en Booth 1.
# 870.8948680954958: Customer 26 está listo para ser atendido en Booth 1.
# 874.3189077914527: Customer 27 está esperando en Booth 2.
# 889.583023612128: Booth 2 vendió un boleto a Customer 24 en 21 segundos.
# 889.583023612128: Customer 24 fue atendido en Booth 2 y compró su boleto.
# 890.583023612128: Customer 27 está listo para ser atendido en Booth 2.
# 923.1701388440672: Booth 2 vendió un boleto a Customer 27 en 21 segundos.
# 923.1701388440672: Customer 27 fue atendido en Booth 2 y compró su boleto.
# 927.4203130629176: Booth 1 vendió un boleto a Customer 26 en 27 segundos.
# 927.4203130629176: Customer 26 fue atendido en Booth 1 y compró su boleto.
# 978.8410501170475: Customer 28 está esperando en Booth 2.
# 978.8410501170475: Customer 28 está listo para ser atendido en Booth 2.
# 1013.4215941299663: Customer 29 está esperando en Booth 2.
# 1034.2283762725156: Booth 2 vendió un boleto a Customer 28 en 21 segundos.
# 1034.2283762725156: Customer 28 fue atendido en Booth 2 y compró su boleto.
# 1035.2283762725156: Customer 29 está listo para ser atendido en Booth 2.
# 1044.124704013647: Customer 30 está esperando en Booth 0.
# 1044.124704013647: Customer 30 está listo para ser atendido en Booth 0.
# 1065.8235829324376: Booth 2 vendió un boleto a Customer 29 en 21 segundos.
# 1065.8235829324376: Customer 29 fue atendido en Booth 2 y compró su boleto.
# 1085.6837956003387: Booth 0 vendió un boleto a Customer 30 en 60 segundos.
# 1085.6837956003387: Customer 30 fue atendido en Booth 0 y compró su boleto.
# 1112.4471303773087: Customer 31 está esperando en Booth 2.
# 1112.4471303773087: Customer 31 está listo para ser atendido en Booth 2.
# 1156.3711124832246: Customer 32 está esperando en Booth 1.
# 1156.3711124832246: Customer 32 está listo para ser atendido en Booth 1.
# 1168.3600457214077: Booth 2 vendió un boleto a Customer 31 en 21 segundos.
# 1168.3600457214077: Customer 31 fue atendido en Booth 2 y compró su boleto.
# 1178.8416835600387: Customer 33 está esperando en Booth 0.
# 1178.8416835600387: Customer 33 está listo para ser atendido en Booth 0.
# 1202.4780600469905: Booth 0 vendió un boleto a Customer 33 en 60 segundos.
# 1202.4780600469905: Customer 33 fue atendido en Booth 0 y compró su boleto.
# 1214.4608639239345: Customer 34 está esperando en Booth 0.
# 1214.4608639239345: Customer 34 está listo para ser atendido en Booth 0.
# 1216.264143602791: Booth 1 vendió un boleto a Customer 32 en 27 segundos.
# 1216.264143602791: Customer 32 fue atendido en Booth 1 y compró su boleto.
# 1240.574516697865: Booth 0 vendió un boleto a Customer 34 en 60 segundos.
# 1240.574516697865: Customer 34 fue atendido en Booth 0 y compró su boleto.
# 1313.161962792205: Customer 35 está esperando en Booth 0.
# 1313.161962792205: Customer 35 está listo para ser atendido en Booth 0.
# 1350.0483614641923: Booth 0 vendió un boleto a Customer 35 en 60 segundos.
# 1350.0483614641923: Customer 35 fue atendido en Booth 0 y compró su boleto.
# 1391.6919043687285: Customer 36 está esperando en Booth 0.
# 1391.6919043687285: Customer 36 está listo para ser atendido en Booth 0.
# 1415.979640755379: Customer 37 está esperando en Booth 1.
# 1415.979640755379: Customer 37 está listo para ser atendido en Booth 1.
# 1435.5274415031736: Booth 0 vendió un boleto a Customer 36 en 60 segundos.
# 1435.5274415031736: Customer 36 fue atendido en Booth 0 y compró su boleto.
# 1453.6366400229024: Customer 38 está esperando en Booth 0.
# 1453.6366400229024: Customer 38 está listo para ser atendido en Booth 0.
# 1474.8227758599237: Booth 1 vendió un boleto a Customer 37 en 27 segundos.
# 1474.8227758599237: Customer 37 fue atendido en Booth 1 y compró su boleto.
# 1478.2187097422498: Booth 0 vendió un boleto a Customer 38 en 60 segundos.
# 1478.2187097422498: Customer 38 fue atendido en Booth 0 y compró su boleto.
# 1510.652656656198: Customer 39 está esperando en Booth 2.
# 1510.652656656198: Customer 39 está listo para ser atendido en Booth 2.
# 1561.3966059624956: Booth 2 vendió un boleto a Customer 39 en 21 segundos.
# 1561.3966059624956: Customer 39 fue atendido en Booth 2 y compró su boleto.
# 1580.1432435667332: Customer 40 está esperando en Booth 1.
# 1580.1432435667332: Customer 40 está listo para ser atendido en Booth 1.
# 1586.0572112716015: Customer 41 está esperando en Booth 1.
# 1586.2197409496584: Customer 42 está esperando en Booth 2.
# 1586.2197409496584: Customer 42 está listo para ser atendido en Booth 2.
# 1616.755302979702: Booth 2 vendió un boleto a Customer 42 en 21 segundos.
# 1616.755302979702: Customer 42 fue atendido en Booth 2 y compró su boleto.
# 1617.5338535934975: Booth 1 vendió un boleto a Customer 40 en 27 segundos.
# 1617.5338535934975: Customer 40 fue atendido en Booth 1 y compró su boleto.
# 1618.5338535934975: Customer 41 está listo para ser atendido en Booth 1.
# 1658.5572981155094: Booth 1 vendió un boleto a Customer 41 en 27 segundos.
# 1658.5572981155094: Customer 41 fue atendido en Booth 1 y compró su boleto.
# 1690.534163518944: Customer 43 está esperando en Booth 0.
# 1690.534163518944: Customer 43 está listo para ser atendido en Booth 0.
# 1714.7905964308522: Booth 0 vendió un boleto a Customer 43 en 60 segundos.
# 1714.7905964308522: Customer 43 fue atendido en Booth 0 y compró su boleto.
# 1725.9656519624036: Customer 44 está esperando en Booth 2.
# 1725.9656519624036: Customer 44 está listo para ser atendido en Booth 2.
# 1743.6884360534864: Customer 45 está esperando en Booth 2.
# 1754.7776037538888: Customer 46 está esperando en Booth 1.
# 1754.7776037538888: Customer 46 está listo para ser atendido en Booth 1.
# 1771.5236317570439: Booth 2 vendió un boleto a Customer 44 en 21 segundos.
# 1771.5236317570439: Customer 44 fue atendido en Booth 2 y compró su boleto.
# 1772.5236317570439: Customer 45 está listo para ser atendido en Booth 2.
# 1796.3527649586738: Booth 1 vendió un boleto a Customer 46 en 27 segundos.
# 1796.3527649586738: Customer 46 fue atendido en Booth 1 y compró su boleto.
# 1823.6686909022662: Booth 2 vendió un boleto a Customer 45 en 21 segundos.
# 1823.6686909022662: Customer 45 fue atendido en Booth 2 y compró su boleto.
# 1826.6592602809915: Customer 47 está esperando en Booth 2.
# 1826.6592602809915: Customer 47 está listo para ser atendido en Booth 2.
# 1870.6170436594007: Booth 2 vendió un boleto a Customer 47 en 21 segundos.
# 1870.6170436594007: Customer 47 fue atendido en Booth 2 y compró su boleto.
# 1952.0128822087624: Customer 48 está esperando en Booth 1.
# 1952.0128822087624: Customer 48 está listo para ser atendido en Booth 1.
# 1952.9963278822536: Customer 49 está esperando en Booth 1.

# %% [markdown]
# ### Recolectamos los datos

# %%
df_events = pd.DataFrame()
df_booths = pd.DataFrame()
df_customers = pd.DataFrame()

for booth in setup.booths:
    df_booths = pd.concat([df_booths, booth.dfBooth])
    df_events = pd.concat([df_events, booth.dfEvents])

for customer in setup.customers:
    df_customers = pd.concat([df_customers, customer.dfCustomer])
    df_events = pd.concat([df_events, customer.dfEvents])

# %% [markdown]
# ### Análisis de la simulación

# %%
# Cuántos boletos vendió cada cabina
summBooths = df_customers.groupby(
    ["ticket_booth"], as_index=False
).agg({
    "name": ["count"]
})
summBooths.columns = ["ticket_booth", "num_customers"]

df_summary = df_booths.merge(
    summBooths,
    left_on="name",
    right_on="ticket_booth",
    how="inner"
)

# %%
df_summary
# Out:
#       name  service_time ticket_booth  num_customers
# 0  Booth 0            60      Booth 0             11
# 1  Booth 1            27      Booth 1             19
# 2  Booth 2            21      Booth 2             20

# %%
# Análisis de eventos por cliente
sample2 = df_events.sort_values(["customer", "time"])
sample2['lead'] = sample2.groupby('customer')['time'].shift(-1)
sample2["time_on_event"] = sample2["lead"] - sample2["time"]

# %%
# Clientes que esperaron más de 1 segundo para ser atendidos
person_waiting = sample2.loc[
    (sample2['time_on_event'] > 10) &
    (sample2['event'] == "waiting in line"), :
]

print(f"Total de clientes que esperaron más de 10 segundo: {person_waiting.shape[0]}")
# Out:
# Total de clientes que esperaron más de 10 segundo: 48

# %%
# Tiempo promedio de espera por cabina
avg_waiting_time = person_waiting.groupby(
    "booth", as_index=False
).agg({
    "time_on_event": ["mean"],
    "customer": ["count"]
})
avg_waiting_time.columns = ["booth", "avg_wait_time", "num_customers"]

# %%
avg_waiting_time
# Out:
#      booth  avg_wait_time  num_customers
# 0  Booth 0      32.971832             11
# 1  Booth 1      82.699063             17
# 2  Booth 2      61.298278             20

# %%
# Tiempo máximo que las cabinas estuvieron activas
timemax = df_events.groupby(
    "booth", as_index=False
).agg({
    "time": ["max"]
})

timemax.columns = ["booth", "time"]
timemax["time"] = timemax["time"] / 60 / 60  # Convertir a horas

# %%
timemax
# Out:
#      booth      time
# 0  Booth 0  0.476331
# 1  Booth 1  0.542499
# 2  Booth 2  0.519616

# %%
# Cuánto tiempo estuvieron activas vs. paradas
printing = sample2.loc[
    sample2["event"] == "ticket sold",
    :
].groupby(
    ["booth"], as_index=False
).agg({
    "time_on_event": ["sum"]
})

printing.columns = ["booth", "time_used"]
printing["time_used"] = printing["time_used"] / 60 / 60  # Convertir a horas
printing["time_slept"] = 2000 / 60 / 60 - printing["time_used"]  # Tiempo total de simulación - tiempo usado

# %%
printing
# Out:
#      booth  time_used  time_slept
# 0  Booth 0        0.0    0.555556
# 1  Booth 1        0.0    0.555556
# 2  Booth 2        0.0    0.555556

# %%
# Tiempo promedio de inactividad entre clientes
sample3 = df_events.sort_values(["booth", "time"])
sample3["lead"] = sample3.groupby("booth")['time'].shift(-1)
sample3["time_on_event"] = sample3["lead"] - sample3["time"]

print_waiting = sample3.loc[
    sample3["event"] == "finished", :
].groupby(
    ["booth"], as_index=False
).agg({
    "time_on_event": ["mean", "median"]
})

print_waiting.columns = ["booth", "mean_wait", "median_wait"]
print_waiting["mean_wait"] = print_waiting["mean_wait"] / 60  # Convertir a minutos
print_waiting["median_wait"] = print_waiting["median_wait"] / 60  # Convertir a minutos

# %%
print_waiting
# Out:
#      booth  mean_wait  median_wait
# 0  Booth 0   2.032080     1.287126
# 1  Booth 1   1.202135     0.819715
# 2  Booth 2   1.227737     0.629680
